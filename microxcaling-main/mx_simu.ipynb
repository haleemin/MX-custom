# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd /content/drive/MyDrive/MX/
# Out:
# /content/drive/MyDrive/MX

# %%
# !git clone https://github.com/microsoft/microxcaling.git
# Out:
# Cloning into 'microxcaling'...
# remote: Enumerating objects: 270, done.
# remote: Counting objects: 100% (49/49), done.
# remote: Compressing objects: 100% (22/22), done.
# remote: Total 270 (delta 36), reused 27 (delta 27), pack-reused 221 (from 1)
# Receiving objects: 100% (270/270), 961.84 KiB | 2.71 MiB/s, done.
# Resolving deltas: 100% (163/163), done.

# %%
# %cd microxcaling/
# Out:
# /content/microxcaling

# %%
# !pip install -r requirements.txt

# %%
# !pip install -e .
# Out:
# Obtaining file:///content/drive/MyDrive/MX/microxcaling
#   Installing build dependencies ... done
#   Checking if build backend supports build_editable ... done
#   Getting requirements to build editable ... done
#   Installing backend dependencies ... done
#   Preparing editable metadata (pyproject.toml) ... done
# ...
#   Building editable for mx (pyproject.toml) ... done
#   Created wheel for mx: filename=mx-1.1.1.dev0+g7bc4195.d20250415-py3-none-any.whl size=8369 sha256=792ea28c3f31888cc76888e16fb29142542416f0f19a29b16f2f29c0610ffbdd
#   Stored in directory: /tmp/pip-ephem-wheel-cache-s61rnlh1/wheels/c2/2a/26/b28417ba4fc0d54eb76d59fa374cee97249984e3f63c30127c
# Successfully built mx
# ...
#   Attempting uninstall: mx
#     Found existing installation: mx 1.1.1.dev0+g7bc4195.d20250415
#     Uninstalling mx-1.1.1.dev0+g7bc4195.d20250415:
#       Successfully uninstalled mx-1.1.1.dev0+g7bc4195.d20250415
# ...

# %%
# !python examples/ffn_mx_auto.py
# Out:
# A module that was compiled using NumPy 1.x cannot be run in
# NumPy 2.0.2 as it may crash. To support both 1.x and 2.x
# versions of NumPy, modules must be compiled with NumPy 2.0.
# Some module may need to rebuild instead e.g. with 'pybind11>=2.12'.
#
# If you are a user of the module, the easiest solution will be to
# downgrade to 'numpy<2' or try to upgrade the affected module.
# We expect that some modules will need time to support NumPy 2.
#
# Traceback (most recent call last):  File "/content/drive/MyDrive/MX/microxcaling/examples/ffn_mx_auto.py", line 1, in <module>
#     import torch
#   File "/usr/local/lib/python3.11/dist-packages/torch/__init__.py", line 1382, in <module>
#     from .functional import *  # noqa: F403
#   File "/usr/local/lib/python3.11/dist-packages/torch/functional.py", line 7, in <module>
#     import torch.nn.functional as F
#   File "/usr/local/lib/python3.11/dist-packages/torch/nn/__init__.py", line 1, in <module>
# ...

# %%
# !python examples/ffn_mx_manual.py \
    --scale_bits 0 \
    --w_elem_format fp6_e3m2 \
    --a_elem_format fp6_e3m2 \
    --block_size 32 \
    --bfloat 16 \
    --custom_cuda
# Out:
# A module that was compiled using NumPy 1.x cannot be run in
# NumPy 2.0.2 as it may crash. To support both 1.x and 2.x
# versions of NumPy, modules must be compiled with NumPy 2.0.
# Some module may need to rebuild instead e.g. with 'pybind11>=2.12'.
#
# If you are a user of the module, the easiest solution will be to
# downgrade to 'numpy<2' or try to upgrade the affected module.
# We expect that some modules will need time to support NumPy 2.
#
# Traceback (most recent call last):  File "/content/drive/MyDrive/MX/microxcaling/examples/ffn_mx_manual.py", line 1, in <module>
#     import torch
#   File "/usr/local/lib/python3.11/dist-packages/torch/__init__.py", line 1382, in <module>
#     from .functional import *  # noqa: F403
#   File "/usr/local/lib/python3.11/dist-packages/torch/functional.py", line 7, in <module>
#     import torch.nn.functional as F
#   File "/usr/local/lib/python3.11/dist-packages/torch/nn/__init__.py", line 1, in <module>
# ...

# %%
# !python examples/ffn.py
# Out:
# A module that was compiled using NumPy 1.x cannot be run in
# NumPy 2.0.2 as it may crash. To support both 1.x and 2.x
# versions of NumPy, modules must be compiled with NumPy 2.0.
# Some module may need to rebuild instead e.g. with 'pybind11>=2.12'.
#
# If you are a user of the module, the easiest solution will be to
# downgrade to 'numpy<2' or try to upgrade the affected module.
# We expect that some modules will need time to support NumPy 2.
#
# Traceback (most recent call last):  File "/content/drive/MyDrive/MX/microxcaling/examples/ffn.py", line 1, in <module>
#     import torch
#   File "/usr/local/lib/python3.11/dist-packages/torch/__init__.py", line 1382, in <module>
#     from .functional import *  # noqa: F403
#   File "/usr/local/lib/python3.11/dist-packages/torch/functional.py", line 7, in <module>
#     import torch.nn.functional as F
#   File "/usr/local/lib/python3.11/dist-packages/torch/nn/__init__.py", line 1, in <module>
#     from .modules import *  # noqa: F403
# ...

# %%
import torch
print(torch.cuda.is_available())
# Out:
# True

# %%
# !python -u examples/compare_y.py
# Out:
# Traceback (most recent call last):
#   File "/content/drive/MyDrive/MX/microxcaling/examples/compare_y.py", line 31, in <module>
#     y_manual = get_y_value("ffn_mx_manual.py", "y_manual:")
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/content/drive/MyDrive/MX/microxcaling/examples/compare_y.py", line 18, in get_y_value
#     raise ValueError(f"{tag} 값을 출력하는 부분을 찾을 수 없습니다.")
# ValueError: y_manual: 값을 출력하는 부분을 찾을 수 없습니다.
